# %%
#对多个推荐算法评价值进行对比
#71种算法，17种的数据区别于其他算法
x = open('sum.txt')
for line in x.readlines():
    print(line)
# Out:
# 整理的librec各种算法测试结果总结
#
#
#
# 18/02/02 14:32:00 INFO ConstantGuessRecommender: Job End.
#
# 18/02/02 14:32:00 INFO RecommenderJob: Evaluator value:MSE is 1.420600479819362
#
# 18/02/02 14:32:00 INFO RecommenderJob: Evaluator value:RMSE is 1.1918894578858235
#
# 18/02/02 14:32:00 INFO RecommenderJob: Evaluator value:MAE is 1.0551086649731867
#
# 18/02/02 14:32:00 INFO RecommenderJob: Evaluator value:MPE is 1.0
#
# 18/02/02 14:32:00 INFO RecommenderJob: Result path is ../result/filmtrust/rating-constantguess-output/constantguess
#
#
#
#
#
#
#
# 18/02/02 14:32:01 INFO GlobalAverageRecommender: Job End.
#
# 18/02/02 14:32:01 INFO RecommenderJob: Evaluator value:MSE is 0.8455905780691007
#
# 18/02/02 14:32:01 INFO RecommenderJob: Evaluator value:RMSE is 0.919559991555255
#
# 18/02/02 14:32:01 INFO RecommenderJob: Evaluator value:MAE is 0.7134762776471231
#
# 18/02/02 14:32:01 INFO RecommenderJob: Evaluator value:MPE is 0.7761783799040362
#
# ...

# %%
# encoding: utf-8
#算法评测结果
from pyecharts import Bar
bar = Bar("baseline")
bar.add("MSE",["ConstantGuess", "GlobalAverage", "ItemAverage", "ItemCluster", "RandomGuess", "UserAverage","UserCluster"], [1.420600479819362, 0.8455905780691007, 0.858894779752652, 0.8174237933813109, 2.4719906562118803, 0.6824501730000522,0.686075844052425],is_more_utils=True)
bar.add("RMSE",["ConstantGuess", "GlobalAverage", "ItemAverage", "ItemCluster", "RandomGuess", "UserAverage","UserCluster"], [1.1918894578858235, 0.919559991555255, 0.9267657631530484, 0.9041149226626618, 1.572256549107645, 0.8261054248702475,0.8282969540282187],is_more_utils=True)
bar
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="1bc4e90c6a074955b91d4235000d91fa" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('1bc4e90c6a074955b91d4235000d91fa'));
# var option =  {
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "data": [
#                 "MSE",
#                 "RMSE"
#             ],
#             "selectedMode": "multiple"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
# ...
